# %% [markdown]
# # Coroner PFD reports involving covid19 in England and Wales

# %%
# import libraries 
import numpy as np
import pandas as pd
from pylab import savefig
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
# %matplotlib inline

# %%
# import data 
df = pd.read_csv("data.csv",thousands=',')
df.head()
# Out:
#   date_of_report        ref     deceased_name              coroner_name  \
# 0      14-Dec-20  2020-0281      Elsie Taylor               Joanne Lees
# 1      23-Nov-20  2020-0248       Elena Wells          Catharine Palmer
# 2      15-Mar-21  2021-0076    Timothy Steele  Veronica Hamilton-Deeley
# 3      19-Feb-21  2021-0069      Brian Button  Veronica Hamilton-Deeley
# 4      16-Dec-20  2020-0286  Patricia Douglas          Dr Nicholas Shaw
#
#                 coroner_area  \
# 0              Black Country
# 1          Brighton and Hove
# 2  City of Brighton and Hove
# 3  City of Brighton and Hove
# 4          County of Cumbria
#
#                                             category  \
# 0                  Emergency Services related deaths
# 1  Mental health related deaths; Emergency servic...
# 2  Hospital Death (Clinical Procedures and medica...
# 3  Hospital Death (Clinical Procedures and medica...
# 4  Community health care and emergency services r...
#
#                         this_report_is_being_sent_to sent_to_correct  \
# 0                    West Midlands Ambulance Service             yes
# 1  Sussex Partnership Foundation NHS Trust; Brigh...             yes
# 2            Sussex Partnership NHS Foundation Trust             yes
# 3  Brighton Sussex University NHS Hospital Trust,...             yes
# 4  Covid-19 Pandemic Response Service and NHS Pat...             yes
#
#    number_sent  number_responded     ...      \
# 0            1                 1     ...
# 1            2                 2     ...
# 2            1                 0     ...
# 3            3                 1     ...
# 4            2                 1     ...
#
#                                  coroners_concerns_5  \
# 0  the discharge notice left by paramedics contai...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                  coroners_concerns_6  \
# 0  The deceased lived alone and suffered with COP...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                       concern_themes  \
# 0  Communication: 1)failure to take informed cons...
# 1               Communication: 1) poor communication
# 2  Failure to follow protocols: 1) failure to fol...
# 3                             Safety: 1)poor systems
# 4     Education and training: 1) Inadequate training
#
#                                     concern_themes_2 concern_themes_3  \
# 0                                                NaN              NaN
# 1  Failure to follow protocols: 1)failure to tria...              NaN
# 2               Communication: 1) Poor communication              NaN
# 3                                                NaN              NaN
# 4  Communication: Failure to keep accurate medica...              NaN
#
#                                   coroners_actions_1  coroners_actions_2  \
# 0  In my opinion action should be taken to preven...                 NaN
# 1  In my opinion action should be taken to preven...                 NaN
# 2  In my opinion action should be taken to preven...                 NaN
# 3  In my opinion action should be taken to preven...                 NaN
# 4  In my opinion action should be taken to preven...                 NaN
#
#    coroners_actions_3  action_themes other_notes
# 0                 NaN            NaN         NaN
# 1                 NaN            NaN         NaN
# 2                 NaN            NaN         NaN
# 3                 NaN            NaN         NaN
# 4                 NaN            NaN         NaN
#
# [5 rows x 45 columns]

# %%
df.describe()
# Out:
#        number_sent  number_responded  no_people        age        sex  \
# count    23.000000         23.000000       23.0  11.000000  23.000000
# mean      1.869565          0.956522        1.0  65.818182   0.782609
# std       0.967863          1.186219        0.0  26.633881   0.421741
# min       1.000000          0.000000        1.0  18.000000   0.000000
# 25%       1.000000          0.000000        1.0  50.000000   1.000000
# 50%       2.000000          1.000000        1.0  76.000000   1.000000
# 75%       2.000000          1.500000        1.0  86.500000   1.000000
# max       5.000000          5.000000        1.0  90.000000   1.000000
#
#        Unnamed: 27  social_history  coroners_actions_2  coroners_actions_3  \
# count          0.0             0.0                 0.0                 0.0
# mean           NaN             NaN                 NaN                 NaN
# std            NaN             NaN                 NaN                 NaN
# min            NaN             NaN                 NaN                 NaN
# 25%            NaN             NaN                 NaN                 NaN
# 50%            NaN             NaN                 NaN                 NaN
# 75%            NaN             NaN                 NaN                 NaN
# max            NaN             NaN                 NaN                 NaN
#
#        action_themes  other_notes
# count            0.0          0.0
# mean             NaN          NaN
# std              NaN          NaN
# min              NaN          NaN
# 25%              NaN          NaN
# 50%              NaN          NaN
# 75%              NaN          NaN
# max              NaN          NaN
