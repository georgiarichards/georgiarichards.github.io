# %% [markdown]
# # Scraping the Courts and Tribunals Judiciary Website to collect Prevent Future Death (PFD) reports

# %%
from requests import get
from requests import ConnectionError
from bs4 import BeautifulSoup
import re
from time import sleep
from time import time
import csv
import pandas as pd

from tqdm.auto import tqdm
    
import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)
 
def get_url(url):
    response = get(url, verify = False)
    html = response.content
    soup = BeautifulSoup(html, "html.parser")
    return soup

def retries(record_url, tries=3):
    for i in range(tries):
        try:
            soup = get_url(record_url)
            return soup
        except (ConnectionError, SSLError):
            if i < tries - 1:
                sleep(2)
                continue
            else:
                return 'Con error'

# %% [markdown]
# # Scraper starts here - last run on Friday, Sep 18 2020, 6.55 pm.

# %%
#Your second value in "range" will be one more than the number of pages that exist on the wesbite
pages = list(range(1,327))

#This loops through all the pages to get the URLs to individual records
page_string = 'https://www.judiciary.uk/subject/prevention-of-future-deaths/page/{}/'
record_urls = []
for page in tqdm(pages):
    soup = get_url(page_string.format(str(page)))
    h5s = soup.find_all('h5', {'class': 'entry-title'})
    for h5 in h5s:
        record_urls.append(h5.a.get('href'))
# Out:
# HBox(children=(IntProgress(value=0, max=326), HTML(value='')))

# %% [markdown]
# Here we check how many records (i.e. cases) were pulled from the urls & the first and last case

# %%
len(record_urls)
# Out:
# 3253

# %%
record_urls[0]
# Out:
# 'https://www.judiciary.uk/publications/danny-holt-scapens/'

# %%
record_urls[-1]
# Out:
# 'https://www.judiciary.uk/publications/phillip-pratt/'

# %% [markdown]
# Here is my second loop. This will go through the lists of URLs I just created above to visit each individual record and pull out and store the text data (info on the decreased/case) and the PDF URL I will use later

# %%
def error_details(e_dict, record_count, record_url, details):
    e_dict['index'] = record_count
    e_dict['url'] = record_url
    e_dict['reason'] = details
    return e_dict

# %%
reg_exp = re.compile(r"’s\s|s\s|'s\s")
text_cats = ['Date of report', 'Ref', 'Deceased name', 'Coroner name', 'Coroner Area', 'Category', "This report is being sent to"]
#First, I create two lists, one for the PDFs and one for the text data
record_text = []
pdf_urls = []
ref_list = []
#I want to loop through each URL & pull out the death information and pdf link for downloading
error_catching = []

record_count = 0
for record_url in tqdm(record_urls):
    try:
        error_dict = {}
        #Calling the retries function
        soup = retries(record_url, tries=5)
        
        if soup == 'Con error':
            print(f"{record_url} could not connect")
            error_catching.append(error_details(error_dict, record_count, record_url, 'Connection Error'))
            record_count +=1
            continue

        #This gets all the text fields from the website to work with
        death_info = soup.find('div', {'class':'entry-content'}).find_all('p')
        
        if not death_info:
            print(f"{record_url} produced no data")
            error_catching.append(error_details(error_dict, record_count, record_url, 'No Text Loaded'))
            record_count +=1
            continue
            
        #Our dictionary that will hold all of the text information that we will eventually append to "record_text"
        blankdict = {}
        
        #This is to handle 1 annoying record with messed up html tags
        if record_url == 'https://www.judiciary.uk/publications/roadsafety/':
            strong = death_info[0].find_all('strong')
            heads = ['date_of_report', 'ref', 'deceased_name', 'coroner_name', 'coroner_area', 'category']
            for st, h in zip(strong,heads):
                blankdict[h] = st.next_sibling.replace(':','').replace('Ref','').strip()
        #And another record with wonky html
        elif record_url == 'https://www.judiciary.uk/publications/helen-sheath/':
            brs = death_info[0].text.split('\n')
            vals = []
            for b in brs:
                vals.append(b.split(':'))
            for v in vals:
                if v[0] == "Coroners name":
                    alt = "coroner_name"
                    blankdict[alt] = v[1].strip().replace('\n','')
                elif v[0] == "Coroners Area":
                    alt = "coroner_area"
                    blankdict[alt] = v[1].strip().replace('\n','')
                else:
                    blankdict[v[0].strip().replace(' ','_').lower()] = v[1].strip().replace('\n','')
        else:        
            #looping through all of the text categories for handling
            for p in death_info:
                #This checks for blank fields and if there is nothing, it skips it
                if p.text.strip() == '':
                    pass
                #This checks for our "Normal" case in which a colon exists and the category is one of the ones we 
                #pre-specified above in the "text_cats" list
                #We also need to account here for one strange record for "Rebecca Evans" which has a weird text error
                #That we manually correct for
                elif ':' in p.text and p.text.split(':')[0] in text_cats and not 'Rebecca-EvansR.pdf' in p.text:
                    #Simply assigning the key and value from strings on either side of the colon, making everything 
                    #lower case and replacing spaces with underscores and also removing any stray semi-colons
                    text_list = p.text.split(':')
                    blankdict[text_list[0].strip().replace(' ','_').lower()] = text_list[1].strip().replace('\n','').replace('\xa0','')

                elif 'Rebecca-EvansR.pdf' in p.text:
                    #This deals with that singular odd record that currently exists as of 8 Nov 2019
                    blankdict['category'] = p.text.split(':')[1].strip().replace('\n','')
                    
                elif ':' not in p.text:
                    #If the string doesn't have a colon, we can't split on it so have to get it into dictionary format
                    #Using an alternate method that counts the length of the thing
                    if any(x in p.text for x in text_cats):
                        t = [x for x in text_cats if x in p.text][0]
                        l = len(t)
                        blankdict[t.replace(' ','_').lower()] = p.text[l+1:].replace('\n','').replace('\xa0','')
                    elif 'Coroners Area' in p.text:
                        blankdict['coroner_area'] = p.text[13:].strip().replace('\n','').replace('\xa0','')
                    else:
                        print("Something we haven't accounted for has happened")

                elif p.text.strip().count(":") == 2:
                    #This corrects for one odd record in which there are 2 colons but should generalize to fix it for
                    #any time this could happen, so long as it happens in the same way
                    text_list = p.text.split(':')
                    new_string = text_list[0] + text_list[1]
                    new_name = re.sub(reg_exp, ' ', new_string).strip()
                    blankdict[new_name.replace(' ','_').lower()] = text_list[2].strip().replace('\n','').replace('\xa0','')

                elif ':' in p.text and p.text.split(':')[0] not in text_cats:
                    #Some field names are in the form of "name_of_decesased" or "name_of_coroner" or are plural/
                    #possessive so this smashes those into our preferred naming formats
                    if 'Name of' in p.text:
                        all_text = p.text.split(':')
                        key_name = all_text[0].split(' ')
                        blankdict[key_name[2].strip() + '_name'] = all_text[-1].strip()
                    else:    
                        new_name = re.sub(reg_exp, ' ', p.text)
                        text_list = new_name.split(':')
                        blankdict[text_list[0].strip().replace(' ','_').lower()] = text_list[1].strip().replace('\n','').replace('\xa0','')
        blankdict['url'] = record_url
        
        #A small little check for duplicated ref names
        try:
            if not blankdict['ref']:
                pass
            elif blankdict['ref'] in ref_list:
                blankdict['ref'] = blankdict['ref'] + 'A'
            ref_list.append(blankdict['ref'])
        except KeyError:
            blankdict['ref'] = ''
            
        #This appends the final dict to the list
        record_text.append(blankdict)
        
        #this is a seperate process to get the PDF URLs (no matter how many there are) and adds them to their own list   
        urls = soup.find_all('li', {'class':'pdf'})
        pdf_list = []
        for url in urls:
            pdf_list.append(url.findNext('a').get('href'))
        pdf_urls.append(pdf_list)
        
        record_count += 1
        
    except Exception as e:
        import sys
        error_desc = f"{str(e)} occurred for {record_url} when trying to work with {p}"
        print(error_desc)
        error_catching.append(error_details(error_dict, record_count, record_url, error_desc))
        
        #Saving this in case we don't like the error catching.
        #import sys
        #raise type(e)(str(e) + '\n' + 'Error for Record: {}, Field: {}'.format(record_url, p)).with_traceback(sys.exc_info()[2])
# Out:
# HBox(children=(IntProgress(value=0, max=3253), HTML(value='')))
# https://www.judiciary.uk/publications/railwayrelateddeaths/ produced no data
# https://www.judiciary.uk/publications/service-personnel-deaths/ produced no data
# https://www.judiciary.uk/publications/policerelateddeaths/ produced no data
# https://www.judiciary.uk/publications/carehomehealth/ produced no data
# https://www.judiciary.uk/publications/statecustodydeath/ produced no data
# https://www.judiciary.uk/publications/hospitaldeath/ produced no data
# https://www.judiciary.uk/publications/drugsalcoholmedication/ produced no data
# https://www.judiciary.uk/publications/commhealthcareemergencyservices/ produced no data

# %% [markdown]
# Here is the third loop to save the PDFs using the deceased Ref as the file name

# %%
#Any errors should print out above, but you can also check the error_catching dict
#Here we just turn it into a dataframe quickly to easily view

error_df = pd.DataFrame(error_catching)
error_df
# Out:
#    index          reason                                                url
# 0   3183  No Text Loaded  https://www.judiciary.uk/publications/railwayr...
# 1   3184  No Text Loaded  https://www.judiciary.uk/publications/service-...
# 2   3185  No Text Loaded  https://www.judiciary.uk/publications/policere...
# 3   3186  No Text Loaded  https://www.judiciary.uk/publications/carehome...
# 4   3187  No Text Loaded  https://www.judiciary.uk/publications/statecus...
# 5   3190  No Text Loaded  https://www.judiciary.uk/publications/hospital...
# 6   3248  No Text Loaded  https://www.judiciary.uk/publications/drugsalc...
# 7   3249  No Text Loaded  https://www.judiciary.uk/publications/commheal...

# %%
def save_file(path_string, name_string):
    with open(path_string.format(name_string), 'wb') as d:
        d.write(myfile.content)

save_path = '/Users/georgiarichards/Desktop/Python/PFDs opioids/All_PDFs5/{}.pdf'

potential_names = ['ref', 'deceased_name', 'date_of_report']

record_count = 0
#This is the final scrape to actually get the URLs and change the name (when possible) to the refs
for r_t, p_u in zip(tqdm(record_text), pdf_urls):
    if not p_u:
        #If there is no pdf at all, we skip it.
        continue
    else:
        #All this does is gets the PDF and downloads it and names it after the reg
        #It looks scary and complicated but all it is doing is varying the name in the case of multiple PDFs
        #Or naming it for the deceased person if there is no Ref value
        #If there is a pdf but no ref or deceased name, this will throw an error and we can adjust.
        try:
            counter = 0
            if len(p_u) > 1:
                for p in p_u:
                    if counter == 0:
                        myfile = get(p)
                        named = False
                        for x in potential_names:
                            try:
                                if r_t[x]:
                                    save_file(save_path, r_t[x])
                                    counter +=1
                                    named = True
                                    break
                                else:
                                    continue
                            except KeyError:
                                continue
                        if not named:       
                            save_file(save_path, 'check_record_{}'.format(record_count))
                            counter +=1

                    else:
                        myfile = get(p)
                        named = False
                        for x in potential_names:
                            try:
                                if r_t[x]:
                                    save_file(save_path, r_t[x] + '_{}'.format(counter))
                                    counter +=1
                                    named = True
                                    break
                                else:
                                    continue
                            except KeyError:
                                continue
                        if not named:
                            save_file(save_path, 'check_record_{}_{}'.format(record_count, counter))
                            counter +=1
                                    
            else:
                myfile = get(p_u[0])
                named = False
                for x in potential_names:
                    try:
                        if r_t[x]:
                            save_file(save_path, r_t[x])
                            named = True
                            break
                        else:
                            continue
                    except KeyError:
                        continue
                if not named:       
                    save_file(save_path, 'check_record_{}'.format(record_count))
            
            record_count += 1
        
        except Exception as e:
            import sys
            if r_t['ref']:
                raise type(e)(str(e) + '\n' + 'Error for Record: {}'.format(r_t['ref'])).with_traceback(sys.exc_info()[2])
            else:
                raise type(e)(str(e) + '\n' + 'Error for Record Number: {}'.format(record_count)).with_traceback(sys.exc_info()[2])
# Out:
# HBox(children=(IntProgress(value=0, max=3245), HTML(value='')))

# %% [markdown]
# This is my final step that puts the text data (info on the decreased/case) into a csv file & adds the date it was pulled

# %%
st = "Date of report: 19 June  2014"
st
# Out:
# 'Date of report: 19 June  2014'

# %%
from datetime import date

headers = ['date_of_report', 'ref', 'deceased_name', 'coroner_name', 'coroner_area', 'category', "this_report_is_being_sent_to", "url"]

with open('death_info_{}.csv'.format(date.today()), 'w', newline='', encoding='utf-8') as deaths_csv:
    writer = csv.DictWriter(deaths_csv, fieldnames=headers)
    writer.writeheader()
    for record in record_text:
        if record == {}:
            pass
        else:
            writer.writerow(record)

# %% [markdown]
# This is an addition few steps to check what differences there are from the Dec month records

# %%
import os

pdfs4 = os.listdir('All_PDFs4')
pdfs5 = os.listdir('All_PDFs5')

new_not_old = set(pdfs5).difference(pdfs4)

new_not_old_list = list(new_not_old)
new_not_old_list.sort()
new_not_old_list
# Out:
# ['.DS_Store',
#  '20016-0092_1.pdf',
#  '2015-0144_1.pdf',
#  '2015-0144_2.pdf',
#  '2015-0144_3.pdf',
#  '2015-0156_1.pdf',
#  '2015-0156_2.pdf',
#  '2015-0256_1.pdf',
#  '2015-0281_2.pdf',
#  '2015-0307_2.pdf',
#  '2015-0315A_2.pdf',
#  '2015-0338_1.pdf',
#  '2015-0372_1.pdf',
#  '2015-0376_1.pdf',
#  '2015-0377_2.pdf',
#  '2015-0378_1.pdf',
#  '2015-0379_1.pdf',
#  '2015-0384_3.pdf',
#  '2015-0392_1.pdf',
#  '2015-0396_1.pdf',
#  '2015-0403_1.pdf',
#  '2015-0407_1.pdf',
#  '2015-0408_1.pdf',
#  '2015-0409_2.pdf',
#  '2015-0409_3.pdf',
#  '2015-0409_4.pdf',
#  '2015-0411_1.pdf',
#  '2015-0411_2.pdf',
#  '2015-0412_2.pdf',
#  '2015-0412_3.pdf',
#  '2015-0417_1.pdf',
#  '2015-0418_1.pdf',
#  '2015-0425_1.pdf',
#  '2015-0426_1.pdf',
#  '2015-0429_1.pdf',
#  '2015-0432_1.pdf',
#  '2015-0433_1.pdf',
#  '2015-0437_1.pdf',
#  '2015-0443_1.pdf',
#  '2015-0443_2.pdf',
#  '2015-0444_1.pdf',
#  '2015-0449_1.pdf',
#  '2015-0450_2.pdf',
#  '2015-0451_1.pdf',
#  '2015-0453_1.pdf',
#  '2015-0453_2.pdf',
#  '2015-0457_1.pdf',
#  '2015-0460_2.pdf',
#  '2015-0463_1.pdf',
#  '2015-0464_1.pdf',
#  '2015-0465_1.pdf',
#  '2015-0466_1.pdf',
#  '2015-0475.pdf',
#  '2015-0475_1.pdf',
#  '2015-0475_2.pdf',
#  '2015-0503_2.pdf',
#  '2016 -0146.pdf',
#  '2016 -0153.pdf',
#  '2016 – 0138_1.pdf',
#  '2016 – 0138_2.pdf',
#  '2016 – 0141_1.pdf',
#  '2016 – 0142_1.pdf',
#  '2016 – 0149.pdf',
#  '2016 – 0149_1.pdf',
#  '2016 – 0272_1.pdf',
#  '2016 – 0278_1.pdf',
#  '2016 – 0283_1.pdf',
#  '2016 – 0290_1.pdf',
#  '2016 – 0294_1.pdf',
#  '2016 – 0302_1.pdf',
#  '2016- 0078_1.pdf',
#  '2016-0001A_1.pdf',
#  '2016-0001A_2.pdf',
#  '2016-0001_1.pdf',
#  '2016-0001_2.pdf',
#  '2016-0012_1.pdf',
#  '2016-0014_1.pdf',
#  '2016-0014_2.pdf',
#  '2016-0017_1.pdf',
#  '2016-0018_1.pdf',
#  '2016-0027_1.pdf',
#  '2016-0028_1.pdf',
#  '2016-0029_1.pdf',
#  '2016-0030A_1.pdf',
#  '2016-0030_1.pdf',
#  '2016-0032_1.pdf',
#  '2016-0032_2.pdf',
#  '2016-0033_1.pdf',
#  '2016-0034_1.pdf',
#  '2016-0035_1.pdf',
#  '2016-0040_1.pdf',
#  '2016-0043_1.pdf',
#  '2016-0045_1.pdf',
#  '2016-0047_1.pdf',
#  '2016-0048_1.pdf',
#  '2016-0049_1.pdf',
#  '2016-0049_2.pdf',
#  '2016-0050_1.pdf',
#  '2016-0051_1.pdf',
#  '2016-0051_2.pdf',
#  '2016-0052_1.pdf',
#  '2016-0055_1.pdf',
#  '2016-0057_1.pdf',
#  '2016-0059_3.pdf',
#  '2016-0060_1.pdf',
#  '2016-0066_1.pdf',
#  '2016-0067_1.pdf',
#  '2016-0067_2.pdf',
#  '2016-0070_1.pdf',
#  '2016-0070_2.pdf',
#  '2016-0075_1.pdf',
#  '2016-0080_1.pdf',
#  '2016-0085_1.pdf',
#  '2016-0088_1.pdf',
#  '2016-0090_2.pdf',
#  '2016-0091_1.pdf',
#  '2016-0093_1.pdf',
#  '2016-0102_1.pdf',
#  '2016-0109_2.pdf',
#  '2016-0110_1.pdf',
#  '2016-0112_2.pdf',
#  '2016-0114_1.pdf',
#  '2016-0115_1.pdf',
#  '2016-0119_1.pdf',
#  '2016-0120_2.pdf',
#  '2016-0122_1.pdf',
#  '2016-0123_2.pdf',
#  '2016-0124_1.pdf',
#  '2016-0129_1.pdf',
#  '2016-0130_1.pdf',
#  '2016-0131_1.pdf',
#  '2016-0135_1.pdf',
#  '2016-0136_2.pdf',
#  '2016-0216_2.pdf',
#  '2016-0219A_2.pdf',
#  '2016-0219_2.pdf',
#  '2016-0247_2.pdf',
#  '2016-0315_1.pdf',
#  '2016-0315_2.pdf',
#  '2016-0321_2.pdf',
#  '2016-0324_1.pdf',
#  '2016-0329_1.pdf',
#  '2016-0332_1.pdf',
#  '2016-0332_2.pdf',
#  '2016-0337_1.pdf',
#  '2016-0404_1.pdf',
#  '2016-0422_1.pdf',
#  '2016-0600.pdf',
#  '2016-0600_1.pdf',
#  '2016-0600_2.pdf',
#  '2016-0600_3.pdf',
#  '2017-0022.pdf',
#  '2017-0024_2.pdf',
#  '2017-0025_2.pdf',
#  '2017-0027_2.pdf',
#  '2017-0051_2.pdf',
#  '2017-0054_1.pdf',
#  '2017-0054_2.pdf',
#  '2017-0061_1.pdf',
#  '2017-0065_1.pdf',
#  '2017-0069A.pdf',
#  '2017-0069A_1.pdf',
#  '2017-0069A_2.pdf',
#  '2017-0072_1.pdf',
#  '2017-0078_1.pdf',
#  '2017-0091_1.pdf',
#  '2017-0093_2.pdf',
#  '2017-0103_1.pdf',
#  '2017-0113_1.pdf',
#  '2017-0115_1.pdf',
#  '2017-0115_2.pdf',
#  '2017-0115_3.pdf',
#  '2017-0125_1.pdf',
#  '2017-0153_1.pdf',
#  '2017-0156_1.pdf',
#  '2017-0158_1.pdf',
#  '2017-0161_1.pdf',
#  '2017-0162_2.pdf',
#  '2017-0166_1.pdf',
#  '2017-0184_1.pdf',
#  '2017-0195_1.pdf',
#  '2017-0202_3.pdf',
#  '2017-0230_1.pdf',
#  '2017-0235_1.pdf',
#  '2017-0244_1.pdf',
#  '2017-0244_2.pdf',
#  '2017-0249_1.pdf',
#  '2017-0250_1.pdf',
#  '2017-0260_1.pdf',
#  '2017-0260_2.pdf',
#  '2017-0266_1.pdf',
#  '2017-0273_1.pdf',
#  '2017-0295_1.pdf',
#  '2017-0305_1.pdf',
#  '2017-0309_1.pdf',
#  '2017-0322_1.pdf',
#  '2017-0323_1.pdf',
#  '2017-0329_4.pdf',
#  '2017-0392_1.pdf',
#  '2017-0417_1.pdf',
#  '2017-0423_2.pdf',
#  '2017-0432_1.pdf',
#  '2017-0435_1.pdf',
#  '2017-0438_1.pdf',
#  '2017-0441_1.pdf',
#  '2017-0451_1.pdf',
#  '2017-0452_1.pdf',
#  '2017-0458_1.pdf',
#  '2017-0494_2.pdf',
#  '2017–0430_1.pdf',
#  '2018-0023_1.pdf',
#  '2018-0031_1.pdf',
#  '2019-0036_1.pdf',
#  '2019-0169_3.pdf',
#  '2019-0169_4.pdf',
#  '2019-0169_5.pdf',
#  '2019-0169_6.pdf',
#  '2019-0174_1.pdf',
#  '2019-0201_1.pdf',
#  '2019-0206_1.pdf',
#  '2019-0206_2.pdf',
#  '2019-0214_1.pdf',
#  '2019-0214_2.pdf',
#  '2019-0218_1.pdf',
#  '2019-0239_1.pdf',
#  '2019-0247_1.pdf',
#  '2019-0258_1.pdf',
#  '2019-0259_2.pdf',
#  '2019-0272_1.pdf',
#  '2019-0276_1.pdf',
#  '2019-0276_2.pdf',
#  '2019-0280_1.pdf',
#  '2019-0282_1.pdf',
#  '2019-0292_1.pdf',
#  '2019-0292_2.pdf',
#  '2019-0292_3.pdf',
#  '2019-0292_4.pdf',
#  '2019-0325_1.pdf',
#  '2019-0330_1.pdf',
#  '2019-0339_1.pdf',
#  '2019-0345_2.pdf',
#  '2019-0345_3.pdf',
#  '2019-0349_1.pdf',
#  '2019-0355_1.pdf',
#  '2019-0362_1.pdf',
#  '2019-0366_1.pdf',
#  '2019-0366_2.pdf',
#  '2019-0366_3.pdf',
#  '2019-0366_4.pdf',
#  '2019-0369_1.pdf',
#  '2019-0369_2.pdf',
#  '2019-0369_3.pdf',
#  '2019-0379_1.pdf',
#  '2019-0383_1.pdf',
#  '2019-0387_1.pdf',
#  '2019-0390_1.pdf',
#  '2019-0390_2.pdf',
#  '2019-0395_1.pdf',
#  '2019-0396_1.pdf',
#  '2019-0396_2.pdf',
#  '2019-0396_3.pdf',
#  '2019-0400A_1.pdf',
#  '2019-0402_1.pdf',
#  '2019-0404_1.pdf',
#  '2019-0404_2.pdf',
#  '2019-0405_1.pdf',
#  '2019-0407_1.pdf',
#  '2019-0407_2.pdf',
#  '2019-0407_3.pdf',
#  '2019-0408_1.pdf',
#  '2019-0408_2.pdf',
#  '2019-0408_3.pdf',
#  '2019-0409_1.pdf',
#  '2019-0412_1.pdf',
#  '2019-0416A_1.pdf',
#  '2019-0416_1.pdf',
#  '2019-0417_1.pdf',
#  '2019-0421_1.pdf',
#  '2019-0422_1.pdf',
#  '2019-0426_1.pdf',
#  '2019-0426_2.pdf',
#  '2019-0427_1.pdf',
#  '2019-0430_1.pdf',
#  '2019-0432_1.pdf',
#  '2019-0433_1.pdf',
#  '2019-0433_2.pdf',
#  '2019-0433_3.pdf',
#  '2019-0434_1.pdf',
#  '2019-0434_2.pdf',
#  '2019-0442_1.pdf',
#  '2019-0442_2.pdf',
#  '2019-0443_1.pdf',
#  '2019-0445_1.pdf',
#  '2019-0445_2.pdf',
#  '2019-0446_1.pdf',
#  '2019-0449_1.pdf',
#  '2019-0452_1.pdf',
#  '2019-0454_1.pdf',
#  '2019-0454_2.pdf',
#  '2019-0456_1.pdf',
#  '2019-0457_1.pdf',
#  '2019-0458_1.pdf',
#  '2019-0462_1.pdf',
#  '2019-0465_1.pdf',
#  '2019-0466.pdf',
#  '2019-0468.pdf',
#  '2019-0468_1.pdf',
#  '2019-0469.pdf',
#  '2019-0469_1.pdf',
#  '2019-0470.pdf',
#  '2019-0472.pdf',
#  '2019-0473.pdf',
#  '2019-0474.pdf',
#  '2019-0476.pdf',
#  '2019-0477.pdf',
#  '2019-0477_1.pdf',
#  '2019-0478.pdf',
#  '2019-0478_1.pdf',
#  '2019-0479.pdf',
#  '2019-0481.pdf',
#  '2019-0481_1.pdf',
#  '2019-0482.pdf',
#  '2019-0482_1.pdf',
#  '2019-0483.pdf',
#  '2019-0484.pdf',
#  '2019-0485.pdf',
#  '2019-0486.pdf',
#  '2019-0486_1.pdf',
#  '2019-0487.pdf',
#  '2019-0488.pdf',
#  '2019-0489.pdf',
#  '2019-0490.pdf',
#  '2019-0491.pdf',
#  '2019-0491_1.pdf',
#  '2019-0491_2.pdf',
#  '2019-0492.pdf',
#  '2019-0493.pdf',
#  '2019-0493_1.pdf',
#  '2019-0494.pdf',
#  '2019-0494_1.pdf',
#  '2019-0494_2.pdf',
#  '2019-0494_3.pdf',
#  '2019-0494_4.pdf',
#  '2019-0495.pdf',
#  '2019-0495A.pdf',
#  '2019-0495A_1.pdf',
#  '2019-0496.pdf',
#  '2019-0497.pdf',
#  '2019-0498.pdf',
#  '2019-0498_1.pdf',
#  '2019-0499.pdf',
#  '2019-0499A.pdf',
#  '2019-0499_1.pdf',
#  '2019-0499_2.pdf',
#  '2019-0500.pdf',
#  '2019-0500_1.pdf',
#  '2019-0503.pdf',
#  '2019-0504.pdf',
#  '2019-0504_1.pdf',
#  '2019-0504_2.pdf',
#  '2019-0504_3.pdf',
#  '2019-0505.pdf',
#  '2019-0505_1.pdf',
#  '2019-0506.pdf',
#  '2019-0506_1.pdf',
#  '2019-0507.pdf',
#  '2019-0507_1.pdf',
#  '2019-0507_2.pdf',
#  '2019-0507_3.pdf',
#  '2019-0507_4.pdf',
#  '2019-0508.pdf',
#  '2019-0508_1.pdf',
#  '2019-0508_2.pdf',
#  '2019-0508_3.pdf',
#  '2019-0509.pdf',
#  '2019-0509A.pdf',
#  '2019-0510.pdf',
#  '2019-0510_1.pdf',
#  '2019–0425_1.pdf',
#  '2019–0450_1.pdf',
#  '2020-0001_1.pdf',
#  '2020-0001_2.pdf',
#  '2020-0001_3.pdf',
#  '2020-0002.pdf',
#  '2020-0003.pdf',
#  '2020-0003_1.pdf',
#  '2020-0003_2.pdf',
#  '2020-0004.pdf',
#  '2020-0004_1.pdf',
#  '2020-0005.pdf',
#  '2020-0005_1.pdf',
#  '2020-0006.pdf',
#  '2020-0006_1.pdf',
#  '2020-0007.pdf',
#  '2020-0007_1.pdf',
#  '2020-0008.pdf',
#  '2020-0008_1.pdf',
#  '2020-0008_2.pdf',
#  '2020-0009.pdf',
#  '2020-0009_1.pdf',
#  '2020-0010.pdf',
#  '2020-0010_1.pdf',
#  '2020-0012.pdf',
#  '2020-0013.pdf',
#  '2020-0014.pdf',
#  '2020-0015.pdf',
#  '2020-0015_1.pdf',
#  '2020-0016.pdf',
#  '2020-0016_1.pdf',
#  '2020-0017.pdf',
#  '2020-0017_1.pdf',
#  '2020-0018.pdf',
#  '2020-0018_1.pdf',
#  '2020-0019.pdf',
#  '2020-0019_1.pdf',
#  '2020-0020.pdf',
#  '2020-0020_1.pdf',
#  '2020-0021.pdf',
#  '2020-0022.pdf',
#  '2020-0022_1.pdf',
#  '2020-0022_2.pdf',
#  '2020-0023.pdf',
#  '2020-0023_1.pdf',
#  '2020-0024.pdf',
#  '2020-0025.pdf',
#  '2020-0026.pdf',
#  '2020-0026_1.pdf',
#  '2020-0027.pdf',
#  '2020-0028.pdf',
#  '2020-0029.pdf',
#  '2020-0030.pdf',
#  '2020-0030_1.pdf',
#  '2020-0030_2.pdf',
#  '2020-0031.pdf',
#  '2020-0032.pdf',
#  '2020-0033.pdf',
#  '2020-0033A.pdf',
#  '2020-0033A_1.pdf',
#  '2020-0033_1.pdf',
#  '2020-0034.pdf',
#  '2020-0034A.pdf',
#  '2020-0035.pdf',
#  '2020-0036.pdf',
#  '2020-0037.pdf',
#  '2020-0037_1.pdf',
#  '2020-0037_2.pdf',
#  '2020-0038.pdf',
#  '2020-0039.pdf',
#  '2020-0040.pdf',
#  '2020-0040_1.pdf',
#  '2020-0040_2.pdf',
#  '2020-0041.pdf',
#  '2020-0042.pdf',
#  '2020-0042_1.pdf',
#  '2020-0043.pdf',
#  '2020-0044.pdf',
#  '2020-0045.pdf',
#  '2020-0045_1.pdf',
#  '2020-0046.pdf',
#  '2020-0047.pdf',
#  '2020-0047_1.pdf',
#  '2020-0048.pdf',
#  '2020-0049.pdf',
#  '2020-0049_1.pdf',
#  '2020-0049_2.pdf',
#  '2020-0050.pdf',
#  '2020-0050_1.pdf',
#  '2020-0051.pdf',
#  '2020-0052.pdf',
#  '2020-0053.pdf',
#  '2020-0054.pdf',
#  '2020-0054_1.pdf',
#  '2020-0055.pdf',
#  '2020-0055_1.pdf',
#  '2020-0056.pdf',
#  '2020-0057.pdf',
#  '2020-0057_1.pdf',
#  '2020-0058.pdf',
#  '2020-0059.pdf',
#  '2020-0059_1.pdf',
#  '2020-0060.pdf',
#  '2020-0060_1.pdf',
#  '2020-0061.pdf',
#  '2020-0062.pdf',
#  '2020-0063.pdf',
#  '2020-0064.pdf',
#  '2020-0064_1.pdf',
#  '2020-0065.pdf',
#  '2020-0065_1.pdf',
#  '2020-0066.pdf',
#  '2020-0067.pdf',
#  '2020-0067_1.pdf',
#  '2020-0068.pdf',
#  '2020-0068_1.pdf',
#  '2020-0069.pdf',
#  '2020-0070.pdf',
#  '2020-0071.pdf',
#  '2020-0071_1.pdf',
#  '2020-0072.pdf',
#  '2020-0073.pdf',
#  '2020-0073_1.pdf',
#  '2020-0074.pdf',
#  '2020-0075.pdf',
#  '2020-0075_1.pdf',
#  '2020-0076.pdf',
#  '2020-0077.pdf',
#  '2020-0078.pdf',
#  '2020-0079.pdf',
#  '2020-0079_1.pdf',
#  '2020-0080.pdf',
#  '2020-0081.pdf',
#  '2020-0081_1.pdf',
#  '2020-0081_2.pdf',
#  '2020-0082.pdf',
#  '2020-0082_1.pdf',
#  '2020-0083.pdf',
#  '2020-0083_1.pdf',
#  '2020-0084.pdf',
#  '2020-0084A.pdf',
#  '2020-0085.pdf',
#  '2020-0086.pdf',
#  '2020-0087.pdf',
#  '2020-0087_1.pdf',
#  '2020-0087_2.pdf',
#  '2020-0088.pdf',
#  '2020-0089.pdf',
#  '2020-0090.pdf',
#  '2020-0091.pdf',
#  '2020-0092.pdf',
#  '2020-0093.pdf',
#  '2020-0094.pdf',
#  '2020-0094_1.pdf',
#  '2020-0095.pdf',
#  '2020-0096.pdf',
#  '2020-0097.pdf',
#  '2020-0098.pdf',
#  '2020-0098_1.pdf',
#  '2020-0099.pdf',
#  '2020-0100.pdf',
#  '2020-0101.pdf',
#  '2020-0102.pdf',
#  '2020-0103.pdf',
#  '2020-0104.pdf',
#  '2020-0105.pdf',
#  '2020-0106.pdf',
#  '2020-0107.pdf',
#  '2020-0108.pdf',
#  '2020-0109.pdf',
#  '2020-0110.pdf',
#  '2020-0111.pdf',
#  '2020-0112.pdf',
#  '2020-0113.pdf',
#  '2020-0114.pdf',
#  '2020-0115.pdf',
#  '2020-0116.pdf',
#  '2020-0118.pdf',
#  '2020-0119.pdf',
#  '2020-0120.pdf',
#  '2020-0121.pdf',
#  '2020-0122.pdf',
#  '2020-0123.pdf',
#  '2020-0124.pdf',
#  '2020-0125.pdf',
#  '2020-0126.pdf',
#  '2020-0127.pdf',
#  '2020-0128.pdf',
#  '2020-0129.pdf',
#  '2020-0130.pdf',
#  '2020-0131.pdf',
#  '2020-0132.pdf',
#  '2020-0133.pdf',
#  '2020-0134.pdf',
#  '2020-0135.pdf',
#  'Allan Beasley.pdf',
#  'Andrew Finlay.pdf',
#  'Andrew Finlay_1.pdf',
#  'Andrew Frere.pdf',
#  'Andrew Reid.pdf',
#  'Andrew Reid_1.pdf',
#  'Andrew Reid_2.pdf',
#  'Andrew Roberts.pdf',
#  'Angela Jackson.pdf',
#  'Angela Jackson_1.pdf',
#  'Angela Jackson_2.pdf',
#  'Barry Pike.pdf',
#  'Ben Hiscox.pdf',
#  'Bryan Catanach.pdf',
#  'Bryan Catanach_1.pdf',
#  'Caliel Smith-Kwami.pdf',
#  'Codrut Iederan.pdf',
#  'Craig Chappell.pdf',
#  'Daniel Ghafuri.pdf',
#  'Darren Browne.pdf',
#  'Darren Jones.pdf',
#  'David Efemena.pdf',
#  'David Stacey_1.pdf',
#  'David Sweeney.pdf',
#  'Dean Barrell.pdf',
#  'Dean Barrell_1.pdf',
#  'Deborah Roberts.pdf',
#  'Denis Plater.pdf',
#  'Edna Cleaton.pdf',
#  'Edna Cleaton_1.pdf',
#  'Edward McGivern.pdf',
#  'Eliza Simpson.pdf',
#  'Elsie Clarke.pdf',
#  'Elsie Clarke_1.pdf',
#  'Eugeniusz Niedziolko.pdf',
#  'Frank Hayward.pdf',
#  'Frank Hayward_1.pdf',
#  'Frederick Sutton.pdf',
#  'Gary Peel.pdf',
#  'Gary Peel_1.pdf',
#  'George Ainsworth.pdf',
#  'Hayley Gascoigne.pdf',
#  'Hayley Gascoigne_1.pdf',
#  'Hubert Kelly.pdf',
#  'Hubert Kelly_1.pdf',
#  'Ian Emsley.pdf',
#  'Isabel Richardson.pdf',
#  'Isabel Richardson_1.pdf',
#  'James Graham.pdf',
#  'James Graham_1.pdf',
#  'Jamil Ahmed.pdf',
#  'John Robinson.pdf',
#  'John Sloan.pdf',
#  'John Waite.pdf',
#  'John Waite_1.pdf',
#  'John Waite_2.pdf',
#  'Joyce Plested.pdf',
#  'Joyce Plested_1.pdf',
#  'Joyce Tozer.pdf',
#  'Joyce Tozer_1.pdf',
#  'Kala Skinner.pdf',
#  'Karen O’Brien.pdf',
#  'Kay Sheard.pdf',
#  'Kay Sheard_1.pdf',
#  'Kenneth Brincombe.pdf',
#  'Kenneth Brincombe_1.pdf',
#  'Kenneth Brincombe_2.pdf',
#  'Laila Habibi.pdf',
#  'Laura Newlands.pdf',
#  'Lee Daniel.pdf',
#  'Lee Daniel_1.pdf',
#  'Lee Rushton.pdf',
#  'Lee Rushton_1.pdf',
#  'Luke Myers.pdf',
#  'Madhumita Mandal.pdf',
#  'Madhumita Mandal_1.pdf',
#  'Madhumita Mandal_2.pdf',
#  'Madhumita Mandal_3.pdf',
#  'Margaret Pegnall.pdf',
#  'Margaret Pegnall_1.pdf',
#  'Margaret Spencer.pdf',
#  'Margaret Spencer_1.pdf',
#  'Marian Grant.pdf',
#  'Marian Grant_1.pdf',
#  'Mark Nicols.pdf',
#  'Mary Hollands.pdf',
#  'Mary Hollands_1.pdf',
#  'Mary James.pdf',
#  'May Hall.pdf',
#  'Michelle Barnes.pdf',
#  'Michelle Barnes_1.pdf',
#  'Mollie Bentham.pdf',
#  'Mollie Bentham_1.pdf',
#  'Naomi Sourbut.pdf',
#  'Olawale Adelusi.pdf',
#  'Olawale Adelusi_1.pdf',
#  'Olive Darbyshire.pdf',
#  'Olive Darbyshire_1.pdf',
#  'Ololade Olaobaju.pdf',
#  'Ololade Olaobaju_1.pdf',
#  'Owen Widlake.pdf',
#  'Paliben Dullabh.pdf',
#  'Paliben Dullabh_1.pdf',
#  'Paul Price.pdf',
#  'Paul Price_1.pdf',
#  'Paul Price_2.pdf',
#  'Richard Hill.pdf',
#  'Richard Hill_1.pdf',
#  'Ricky Hudson.pdf',
#  'Ricky Hudson_1.pdf',
#  'Robert Mansfield.pdf',
#  'Ronald Bonifield.pdf',
#  'Rosalind Baird.pdf',
#  'Roy Millar.pdf',
#  'Shane Hardy.pdf',
#  'Sharon Henshall.pdf',
#  'Sharon Henshall_1.pdf',
#  'Stanford Bell.pdf',
#  'Stanford Bell_1.pdf',
#  'Stanford Bell_2.pdf',
#  'Stephen Adams.pdf',
#  'Stephen O’Malley.pdf',
#  'Stephen Taylor.pdf',
#  'Stephen Taylor_1.pdf',
#  'Steven Curtis.pdf',
#  'Sufia Begum.pdf',
#  'Sufia Begum_1.pdf',
#  'Sufia Begum_2.pdf',
#  'Thelma Clarkson.pdf',
#  'Thomas Jordan.pdf',
#  'Thomas Lear.pdf',
#  'Thomas Nicholls.pdf',
#  'Tommy Faisali.pdf',
#  'William Savage.pdf',
#  'William Savage_1.pdf']

# %%
len(new_not_old_list)
# Out:
# 708

# %%
aug = pd.read_csv('death_info_2020-08-14.csv')
sep = pd.read_csv('death_info_2020-09-19.csv')

# %%
cols = list(aug.columns)
merged = sep.merge(aug, on=cols, how='left', indicator=True)

# %%
l_only = merged[merged['_merge'] == 'left_only']

# %%
len(l_only)
# Out:
# 10

# %%
l_only
# Out:
#         date_of_report        ref             deceased_name    coroner_name  \
# 0        24 March 2020  2020-0135        Danny Holt-Scapens     Rachel Syed
# 1         26 June 2020  2020-0134          Gary Etherington   Andrew Harris
# 2         22 June 2020  2020-0133             Bethan Harris   Séan Cummings
# 3         25 June 2020  2020-0132  Winifred (Mary) Redfearn    David Ridley
# 4         15 June 2020  2020-0131           Grant Macdonald  Anita Bhardwaj
# 5     17 December 2018  2020-0130          Bertram Crawford    Maria Voisin
# 6           30/01/2020  2020-0129            Julie O’Connor    Maria Voisin
# 7         16 June 2020  2020-0128             Joan Williams   Emma Whitting
# 8          3 June 2020  2020-0127                Allan Watt   Nicholas Shaw
# 1536   25 January 2017  2017-0022     Geraldine Butterfield   Anna Crawford
#
#                         coroner_area  \
# 0                    Manchester West
# 1                 Inner South London
# 2                        West London
# 3              Wiltshire and Swindon
# 4           Liverpool and the Wirral
# 5                               Avon
# 6                               Avon
# 7     Bedfordshire and Luton Coroner
# 8                            Cumbria
# 1536                          Surrey
#
#                                                category  \
# 0     Mental Health related deaths; Community health...
# 1     Mental Health related deaths; Community health...
# 2     Hospital death (Clinical procedures and medica...
# 3     Hospital death (Clinical procedures and medica...
# 4                 Road (Highways Safety) related deaths
# 5                                  Other related deaths
# 6                   Community healthcare related deaths
# 7                 Road (Highways Safety) related deaths
# 8     Hospital Death (Clinical Procedures and Medica...
# 1536                    Care Home Health related deaths
#
#                            this_report_is_being_sent_to  \
# 0     North West Boroughs Healthcare NHS Foundation ...
# 1                           Oxleas NHS Foundation Trust
# 2     St. George’s University Hospitals NHS Foundati...
# 3       The Great Western Hospital NHS Foundation Trust
# 4             Liverpool City Council; Merseyside Police
# 5                            Suspension Bridge Trustees
# 6     Department for Health and Social Care; Royal C...
# 7                              Department for Transport
# 8                   North Cumbria Integrated Care Trust
# 1536                           Collingwood Nursing Home
#
#                                                     url     _merge
# 0     https://www.judiciary.uk/publications/danny-ho...  left_only
# 1     https://www.judiciary.uk/publications/gary-eth...  left_only
# 2     https://www.judiciary.uk/publications/bethan-h...  left_only
# 3     https://www.judiciary.uk/publications/winifred...  left_only
# 4     https://www.judiciary.uk/publications/grant-ma...  left_only
# 5     https://www.judiciary.uk/publications/bertram-...  left_only
# 6     https://www.judiciary.uk/publications/julie-oc...  left_only
# 7     https://www.judiciary.uk/publications/joan-wil...  left_only
# 8     https://www.judiciary.uk/publications/allan-watt/  left_only
# 1536  https://www.judiciary.uk/publications/geraldin...  left_only

# %%
l_only.to_csv(r'death_info_newsep19.csv')

# %% [markdown]
# Data processing for website

# %%
sep_names = pd.read_csv('death_info_2020-09-19.csv')
sep_names.head()
# Out:
#   date_of_report        ref             deceased_name    coroner_name  \
# 0  24 March 2020  2020-0135        Danny Holt-Scapens     Rachel Syed
# 1   26 June 2020  2020-0134          Gary Etherington   Andrew Harris
# 2   22 June 2020  2020-0133             Bethan Harris   Séan Cummings
# 3   25 June 2020  2020-0132  Winifred (Mary) Redfearn    David Ridley
# 4   15 June 2020  2020-0131           Grant Macdonald  Anita Bhardwaj
#
#                coroner_area  \
# 0           Manchester West
# 1        Inner South London
# 2               West London
# 3     Wiltshire and Swindon
# 4  Liverpool and the Wirral
#
#                                             category  \
# 0  Mental Health related deaths; Community health...
# 1  Mental Health related deaths; Community health...
# 2  Hospital death (Clinical procedures and medica...
# 3  Hospital death (Clinical procedures and medica...
# 4              Road (Highways Safety) related deaths
#
#                         this_report_is_being_sent_to  \
# 0  North West Boroughs Healthcare NHS Foundation ...
# 1                        Oxleas NHS Foundation Trust
# 2  St. George’s University Hospitals NHS Foundati...
# 3    The Great Western Hospital NHS Foundation Trust
# 4          Liverpool City Council; Merseyside Police
#
#                                                  url
# 0  https://www.judiciary.uk/publications/danny-ho...
# 1  https://www.judiciary.uk/publications/gary-eth...
# 2  https://www.judiciary.uk/publications/bethan-h...
# 3  https://www.judiciary.uk/publications/winifred...
# 4  https://www.judiciary.uk/publications/grant-ma...

# %%
sep_names['deceased_name'] = sep_names['deceased_name'].fillna("")

# %%
sep_names['deceased_name'] = sep_names['deceased_name'].apply(lambda x: ''.join(i[0] for i in x.split()))

# %%
sep_names['deceased_name'] = sep_names['deceased_name'].str.replace('\W', '')

# %%
sep_names.head()
# Out:
#   date_of_report        ref deceased_name    coroner_name  \
# 0  24 March 2020  2020-0135            DH     Rachel Syed
# 1   26 June 2020  2020-0134            GE   Andrew Harris
# 2   22 June 2020  2020-0133            BH   Séan Cummings
# 3   25 June 2020  2020-0132            WR    David Ridley
# 4   15 June 2020  2020-0131            GM  Anita Bhardwaj
#
#                coroner_area  \
# 0           Manchester West
# 1        Inner South London
# 2               West London
# 3     Wiltshire and Swindon
# 4  Liverpool and the Wirral
#
#                                             category  \
# 0  Mental Health related deaths; Community health...
# 1  Mental Health related deaths; Community health...
# 2  Hospital death (Clinical procedures and medica...
# 3  Hospital death (Clinical procedures and medica...
# 4              Road (Highways Safety) related deaths
#
#                         this_report_is_being_sent_to  \
# 0  North West Boroughs Healthcare NHS Foundation ...
# 1                        Oxleas NHS Foundation Trust
# 2  St. George’s University Hospitals NHS Foundati...
# 3    The Great Western Hospital NHS Foundation Trust
# 4          Liverpool City Council; Merseyside Police
#
#                                                  url
# 0  https://www.judiciary.uk/publications/danny-ho...
# 1  https://www.judiciary.uk/publications/gary-eth...
# 2  https://www.judiciary.uk/publications/bethan-h...
# 3  https://www.judiciary.uk/publications/winifred...
# 4  https://www.judiciary.uk/publications/grant-ma...

# %%
sep_names.to_csv('death_info_2020-09-19_processed.csv')
